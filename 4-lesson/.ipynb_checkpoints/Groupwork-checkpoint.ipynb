# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('earthquake_data_tsunami.csv')
df
# Out:
#      magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0          7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1          6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2          7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3          7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4          6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
# ..         ...  ...  ...  ...  ...    ...   ...      ...       ...        ...
# 777        7.7    0    8  912  427  0.000   0.0   60.000   13.0490    -88.660
# 778        6.9    5    7  745    0  0.000   0.0   36.400   56.7744   -153.281
# 779        7.1    0    7  776  372  0.000   0.0  103.000  -14.9280    167.170
# 780        6.8    0    5  711   64  0.000   0.0   33.000    6.6310    126.899
# 781        7.5    0    7  865  324  0.000   0.0   33.000    6.8980    126.579
#
#      Year  Month  tsunami
# ...

# %%
df.head(10)
# Out:
#    magnitude  cdi  mmi   sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7   768  117  0.509  17.0   14.000   -9.7963   159.5960
# 1        6.9    4    4   735   99  2.229  34.0   25.000   -4.9559   100.7380
# 2        7.0    3    3   755  147  3.125  18.0  579.000  -20.0508  -178.3460
# 3        7.3    5    5   833  149  1.865  21.0   37.000  -19.2918  -172.1290
# 4        6.6    0    2   670  131  4.998  27.0  624.464  -25.5948   178.2780
# 5        7.0    4    3   755  142  4.578  26.0  660.000  -26.0442   178.3810
# 6        6.8    1    3   711  136  4.678  22.0  630.379  -25.9678   178.3630
# 7        6.7    7    6   797  145  1.151  37.0   20.000    7.6712   -82.3396
# 8        6.8    8    7  1179  175  2.137  92.0   20.000   18.3300  -102.9130
# 9        7.6    9    8  1799  271  1.153  69.0   26.943   18.3667  -103.2520
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# ...

# %%
df.describe()
# Out:
#         magnitude         cdi         mmi        dmin         gap       depth  \
# count  779.000000  779.000000  779.000000  779.000000  779.000000  779.000000
# mean     6.941027    4.331194    5.969191    1.323336   25.046842   75.382108
# std      0.446360    3.172940    1.459505    2.221712   24.266577  136.322435
# min      6.500000    0.000000    1.000000    0.000000    0.000000    2.700000
# 25%      6.600000    0.000000    5.000000    0.000000   14.400000   14.000000
# 50%      6.800000    5.000000    6.000000    0.000000   20.000000   26.590000
# 75%      7.100000    7.000000    7.000000    1.846500   30.000000   49.500000
# max      9.100000    9.000000    9.000000   17.654000  239.000000  670.810000
#
#          latitude   longitude         Year       Month     tsunami
# count  779.000000  779.000000   779.000000  779.000000  779.000000
# mean     3.596402   52.706554  2012.242619    6.546855    0.387677
# ...

# %%
# Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  782 non-null    float64
#  1   cdi        782 non-null    int64
#  2   mmi        782 non-null    int64
#  3   sig        782 non-null    int64
#  4   nst        782 non-null    int64
#  5   dmin       782 non-null    float64
#  6   gap        782 non-null    float64
#  7   depth      782 non-null    float64
#  8   latitude   782 non-null    float64
#  9   longitude  782 non-null    float64
#  10  Year       782 non-null    int64
#  11  Month      782 non-null    int64
#  12  tsunami    782 non-null    int64
# dtypes: float64(6), int64(7)
# memory usage: 79.6 KB

# %%
# Visualising missing data
df.isnull().sum()
# Out:
# magnitude    0
# cdi          0
# mmi          0
# sig          0
# nst          0
# dmin         0
# gap          0
# depth        0
# latitude     0
# longitude    0
# Year         0
# Month        0
# tsunami      0
# dtype: int64

# %%
# Visualizing the integers here
missing = df.isnull().astype(int)
plt.figure(figsize=(10,6))
plt.imshow(missing, aspect='auto', cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Missing Value (1 = Missing, 0 = Present)')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values Heatmap')
plt.xticks(rotation=90)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(-2.0, 0, '−2'),
#   Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14')])

# %%
# Visualizing the floats here
missing = df.isnull().astype(float)
plt.figure(figsize=(10,6))
plt.imshow(missing, aspect='auto', cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Missing Value (1 = Missing, 0 = Present)')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values Heatmap')
plt.xticks(rotation=90)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12., 14.]),
#  [Text(-2.0, 0, '−2'),
#   Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14')])

# %%
df_corr = df.corr()

# %%
# Visualizing using heatmap via Seaborn

plt.figure(figsize=(12, 8))
sns.heatmap(
    df_corr,
    annot=True,              # Show correlation values
    fmt=".2f",               # Format to 2 decimal places
    cmap="Blues",            # Color palette for contrast
    vmin=-1, vmax=1,         # Fix scale for consistency
    linewidths=0.5,          # Add lines between cells
    linecolor='gray',        # Line color
    square=True,             # Make cells square
    cbar_kws={"shrink": 0.8} # Shrink color bar
)
plt.title("Correlation Matrix", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

# %%
# Dropping some columns and rows (assume that there were many missing values so not useful)
df = df.drop(['sig', 'nst'], axis=1)
df = df.drop([0, 1, 2])
df
# Out:
#      magnitude  cdi  mmi   dmin   gap    depth  latitude  longitude  Year  \
# 3          7.3    5    5  1.865  21.0   37.000  -19.2918  -172.1290  2022
# 4          6.6    0    2  4.998  27.0  624.464  -25.5948   178.2780  2022
# 5          7.0    4    3  4.578  26.0  660.000  -26.0442   178.3810  2022
# 6          6.8    1    3  4.678  22.0  630.379  -25.9678   178.3630  2022
# 7          6.7    7    6  1.151  37.0   20.000    7.6712   -82.3396  2022
# ..         ...  ...  ...    ...   ...      ...       ...        ...   ...
# 777        7.7    0    8  0.000   0.0   60.000   13.0490   -88.6600  2001
# 778        6.9    5    7  0.000   0.0   36.400   56.7744  -153.2810  2001
# 779        7.1    0    7  0.000   0.0  103.000  -14.9280   167.1700  2001
# 780        6.8    0    5  0.000   0.0   33.000    6.6310   126.8990  2001
# 781        7.5    0    7  0.000   0.0   33.000    6.8980   126.5790  2001
#
#      Month  tsunami
# 3       11        1
# 4       11        1
# ...

# %%
# Resetting the index after formatting
df = df.reset_index(drop=True)
df
# Out:
#      magnitude  cdi  mmi   dmin   gap    depth  latitude  longitude  Year  \
# 0          7.3    5    5  1.865  21.0   37.000  -19.2918  -172.1290  2022
# 1          6.6    0    2  4.998  27.0  624.464  -25.5948   178.2780  2022
# 2          7.0    4    3  4.578  26.0  660.000  -26.0442   178.3810  2022
# 3          6.8    1    3  4.678  22.0  630.379  -25.9678   178.3630  2022
# 4          6.7    7    6  1.151  37.0   20.000    7.6712   -82.3396  2022
# ..         ...  ...  ...    ...   ...      ...       ...        ...   ...
# 774        7.7    0    8  0.000   0.0   60.000   13.0490   -88.6600  2001
# 775        6.9    5    7  0.000   0.0   36.400   56.7744  -153.2810  2001
# 776        7.1    0    7  0.000   0.0  103.000  -14.9280   167.1700  2001
# 777        6.8    0    5  0.000   0.0   33.000    6.6310   126.8990  2001
# 778        7.5    0    7  0.000   0.0   33.000    6.8980   126.5790  2001
#
#      Month  tsunami
# 0       11        1
# 1       11        1
# ...
