# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('earthquake_data_tsunami.csv')
df
# Out:
#      magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0          7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1          6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2          7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3          7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4          6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
# ..         ...  ...  ...  ...  ...    ...   ...      ...       ...        ...
# 777        7.7    0    8  912  427  0.000   0.0   60.000   13.0490    -88.660
# 778        6.9    5    7  745    0  0.000   0.0   36.400   56.7744   -153.281
# 779        7.1    0    7  776  372  0.000   0.0  103.000  -14.9280    167.170
# 780        6.8    0    5  711   64  0.000   0.0   33.000    6.6310    126.899
# 781        7.5    0    7  865  324  0.000   0.0   33.000    6.8980    126.579
#
#      Year  Month  tsunami
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  782 non-null    float64
#  1   cdi        782 non-null    int64
#  2   mmi        782 non-null    int64
#  3   sig        782 non-null    int64
#  4   nst        782 non-null    int64
#  5   dmin       782 non-null    float64
#  6   gap        782 non-null    float64
#  7   depth      782 non-null    float64
#  8   latitude   782 non-null    float64
#  9   longitude  782 non-null    float64
#  10  Year       782 non-null    int64
#  11  Month      782 non-null    int64
#  12  tsunami    782 non-null    int64
# dtypes: float64(6), int64(7)
# memory usage: 79.6 KB

# %%
df.drop_duplicates()
# Out:
#      magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0          7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1          6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2          7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3          7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4          6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
# ..         ...  ...  ...  ...  ...    ...   ...      ...       ...        ...
# 777        7.7    0    8  912  427  0.000   0.0   60.000   13.0490    -88.660
# 778        6.9    5    7  745    0  0.000   0.0   36.400   56.7744   -153.281
# 779        7.1    0    7  776  372  0.000   0.0  103.000  -14.9280    167.170
# 780        6.8    0    5  711   64  0.000   0.0   33.000    6.6310    126.899
# 781        7.5    0    7  865  324  0.000   0.0   33.000    6.8980    126.579
#
#      Year  Month  tsunami
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['magnitude'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(8,6))
img = plt.imread('map.png')
plt.imshow(img, extent=[126, 130, 34, 38], origin='upper')
plt.scatter(df['longitude'], df['latitude'], s=40, alpha=0.2, c='r')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Data Points')
# Out:
# Text(0.5, 1.0, 'Geographical Data Points')

# %%
plt.figure(figsize=(20, 15))
img = plt.imread('map.png')

# Dynamic extent based on data
lon_min, lon_max = df['longitude'].min(), df['longitude'].max()
lat_min, lat_max = df['latitude'].min(), df['latitude'].max()

# Add a little margin around points
lon_pad = (lon_max - lon_min) * 0.1
lat_pad = (lat_max - lat_min) * 0.1

plt.imshow(img, extent=[lon_min - lon_pad, lon_max + lon_pad,
                        lat_min - lat_pad, lat_max + lat_pad])

plt.scatter(df['longitude'], df['latitude'], s=150, alpha=0.1, c='r')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Data Points')
plt.show()

# %%
df.describe()
# Out:
#         magnitude         cdi         mmi          sig         nst  \
# count  782.000000  782.000000  782.000000   782.000000  782.000000
# mean     6.941125    4.333760    5.964194   870.108696  230.250639
# std      0.445514    3.169939    1.462724   322.465367  250.188177
# min      6.500000    0.000000    1.000000   650.000000    0.000000
# 25%      6.600000    0.000000    5.000000   691.000000    0.000000
# 50%      6.800000    5.000000    6.000000   754.000000  140.000000
# 75%      7.100000    7.000000    7.000000   909.750000  445.000000
# max      9.100000    9.000000    9.000000  2910.000000  934.000000
#
#              dmin         gap       depth    latitude   longitude  \
# count  782.000000  782.000000  782.000000  782.000000  782.000000
# mean     1.325757   25.038990   75.883199    3.538100   52.609199
# std      2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    2.700000  -61.848400 -179.968000
# ...

# %%
df.isnull().sum()
# Out:
# magnitude    0
# cdi          0
# mmi          0
# sig          0
# nst          0
# dmin         0
# gap          0
# depth        0
# latitude     0
# longitude    0
# Year         0
# Month        0
# tsunami      0
# dtype: int64

# %%
df_corr=df.corr()

# %%
sorted_corr = df_corr['tsunami'].abs().sort_values(ascending=False)
sorted_corr
# Out:
# tsunami      1.000000
# Year         0.647211
# nst          0.600231
# dmin         0.400752
# cdi          0.160266
# mmi          0.147363
# longitude    0.136778
# gap          0.116360
# latitude     0.113209
# depth        0.056814
# Month        0.022028
# sig          0.015500
# magnitude    0.004726
# Name: tsunami, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(
    df_corr,
    annot=True,              # Show correlation values
    fmt=".2f",               # Format to 2 decimal places
    cmap="Blues",         # Color palette for contrast
    vmin=-1, vmax=1,         # Fix scale for consistency
    linewidths=0.5,          # Add lines between cells
    linecolor='gray',        # Line color
    square=True,             # Make cells square
    cbar_kws={"shrink": 0.8} # Shrink color bar
)
plt.title("Correlation Matrix", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

# %%
df
# Out:
#      magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0          7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1          6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2          7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3          7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4          6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
# ..         ...  ...  ...  ...  ...    ...   ...      ...       ...        ...
# 777        7.7    0    8  912  427  0.000   0.0   60.000   13.0490    -88.660
# 778        6.9    5    7  745    0  0.000   0.0   36.400   56.7744   -153.281
# 779        7.1    0    7  776  372  0.000   0.0  103.000  -14.9280    167.170
# 780        6.8    0    5  711   64  0.000   0.0   33.000    6.6310    126.899
# 781        7.5    0    7  865  324  0.000   0.0   33.000    6.8980    126.579
#
#      Year  Month  tsunami
# ...

# %%
tsunami_counts = df[df['tsunami']==1]
tsunami_counts
# Out:
#      magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0          7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 2          7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3          7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4          6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
# 5          7.0    4    3  755  142  4.578  26.0  660.000  -26.0442    178.381
# ..         ...  ...  ...  ...  ...    ...   ...      ...       ...        ...
# 408        6.9    5    5  904  562  0.000  23.7  145.000    1.1350    -77.393
# 409        7.1    9    6  780  334  0.000  16.5   21.000  -10.9280    166.018
# 410        6.8    0    7  711  400  0.000  17.5   12.000  -10.8380    165.969
# 411        6.7    0    6  691  387  0.000  26.5   11.000  -10.9970    165.655
# 414        8.0    8    7  993  460  0.000  20.9   24.000  -10.7990    165.114
#
#      Year  Month  tsunami
# ...

# %%
tsunami_counts_sorted_by_year = tsunami_counts.groupby('Year').size()
tsunami_counts_sorted_by_year
# Out:
# Year
# 2013    34
# 2014    40
# 2015    33
# 2016    31
# 2017    27
# 2018    33
# 2019    26
# 2020    15
# 2021    33
# 2022    32
# dtype: int64

# %%
plt.figure(figsize=(12,6))
tsunami_counts_sorted_by_year.plot(kind='bar', color='skyblue')
plt.title('Tsunami Events per Year')
plt.xlabel('Year')
plt.ylabel('Tsunami Counts')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
df2 = pd.read_csv('air_quality_global.csv')
df2
# Out:
#           city  country  latitude  longitude  year  month  pm25_ugm3  \
# 0     New York      USA   40.7128   -74.0060  1999      1      18.11
# 1     New York      USA   40.7128   -74.0060  1999      2      27.79
# 2     New York      USA   40.7128   -74.0060  1999      3      12.05
# 3     New York      USA   40.7128   -74.0060  1999      4      35.25
# 4     New York      USA   40.7128   -74.0060  1999      5      38.39
# ...        ...      ...       ...        ...   ...    ...        ...
# 6475     Lagos  Nigeria    6.5244     3.3792  2025      8      54.42
# 6476     Lagos  Nigeria    6.5244     3.3792  2025      9      42.11
# 6477     Lagos  Nigeria    6.5244     3.3792  2025     10      23.76
# 6478     Lagos  Nigeria    6.5244     3.3792  2025     11      47.28
# 6479     Lagos  Nigeria    6.5244     3.3792  2025     12      24.82
#
#       no2_ugm3 data_quality           measurement_method   data_source
# ...

# %%
df2.drop(columns=df['latitude'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df2.drop(columns=df['latitude'])
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)
#    5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)
#    5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# ...
