# %%
import pandas as pd

# %%
df = pd.read_csv('new_dataset.csv')
df
# Out:
#       Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0              0  2008      1           3          4   2003.0        1955
# 1              1  2008      1           3          4    754.0         735
# 2              2  2008      1           3          4    628.0         620
# 3              4  2008      1           3          4   1829.0        1755
# 4              5  2008      1           3          4   1940.0        1915
# ...          ...   ...    ...         ...        ...      ...         ...
# 1995        3145  2008      1           4          5   2038.0        2005
# 1996        3147  2008      1           4          5   1629.0        1615
# 1997        3148  2008      1           4          5   1254.0        1225
# 1998        3150  2008      1           4          5   1702.0        1625
# 1999        3151  2008      1           4          5    916.0         910
#
#       ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0      2211.0        2225            WN  ...     4.0     8.0          0
# 1      1002.0        1000            WN  ...     5.0    10.0          0
# 2       804.0         750            WN  ...     3.0    17.0          0
# 3      1959.0        1925            WN  ...     3.0    10.0          0
# 4      2121.0        2110            WN  ...     4.0    10.0          0
# ...       ...         ...           ...  ...     ...     ...        ...
# 1995   2226.0        2205            WN  ...     3.0    11.0          0
# 1996   1828.0        1815            WN  ...     7.0    13.0          0
# 1997   1432.0        1350            WN  ...     4.0    13.0          0
# 1998   1831.0        1750            WN  ...     3.0     9.0          0
# 1999   1049.0        1055            WN  ...     7.0    12.0          0
#
#       CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                    N         0           NaN           NaN      NaN
# 1                    N         0           NaN           NaN      NaN
# 2                    N         0           NaN           NaN      NaN
# 3                    N         0           2.0           0.0      0.0
# 4                    N         0           NaN           NaN      NaN
# ...                ...       ...           ...           ...      ...
# 1995                 N         0           8.0           0.0      0.0
# 1996                 N         0           NaN           NaN      NaN
# 1997                 N         0          20.0           0.0     13.0
# 1998                 N         0          10.0           0.0      4.0
# 1999                 N         0           NaN           NaN      NaN
#
#      SecurityDelay  LateAircraftDelay
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              0.0               32.0
# 4              NaN                NaN
# ...            ...                ...
# 1995           0.0               13.0
# 1996           NaN                NaN
# 1997           0.0                9.0
# 1998           0.0               27.0
# 1999           NaN                NaN
#
# [2000 rows x 30 columns]

# %%
df = df.drop(columns=['Unnamed: 0', 'Year', 'Month', 'UniqueCarrier'])

# %%
df
# Out:
#       DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0              3          4   2003.0        1955   2211.0        2225
# 1              3          4    754.0         735   1002.0        1000
# 2              3          4    628.0         620    804.0         750
# 3              3          4   1829.0        1755   1959.0        1925
# 4              3          4   1940.0        1915   2121.0        2110
# ...          ...        ...      ...         ...      ...         ...
# 1995           4          5   2038.0        2005   2226.0        2205
# 1996           4          5   1629.0        1615   1828.0        1815
# 1997           4          5   1254.0        1225   1432.0        1350
# 1998           4          5   1702.0        1625   1831.0        1750
# 1999           4          5    916.0         910   1049.0        1055
#
#       FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  ...  TaxiIn  \
# 0           335  N712SW              128.0           150.0  ...     4.0
# 1          3231  N772SW              128.0           145.0  ...     5.0
# 2           448  N428WN               96.0            90.0  ...     3.0
# 3          3920  N464WN               90.0            90.0  ...     3.0
# 4           378  N726SW              101.0           115.0  ...     4.0
# ...         ...     ...                ...             ...  ...     ...
# 1995        977  N363SW              168.0           180.0  ...     3.0
# 1996       2124  N312SW              179.0           180.0  ...     7.0
# 1997        130  N320SW               98.0            85.0  ...     4.0
# 1998       1852  N217JC               89.0            85.0  ...     3.0
# 1999       2360  N494WN               93.0           105.0  ...     7.0
#
#       TaxiOut  Cancelled CancellationCode Diverted  CarrierDelay  \
# 0         8.0          0                N        0           NaN
# 1        10.0          0                N        0           NaN
# 2        17.0          0                N        0           NaN
# 3        10.0          0                N        0           2.0
# 4        10.0          0                N        0           NaN
# ...       ...        ...              ...      ...           ...
# 1995     11.0          0                N        0           8.0
# 1996     13.0          0                N        0           NaN
# 1997     13.0          0                N        0          20.0
# 1998      9.0          0                N        0          10.0
# 1999     12.0          0                N        0           NaN
#
#       WeatherDelay  NASDelay  SecurityDelay LateAircraftDelay
# 0              NaN       NaN            NaN               NaN
# 1              NaN       NaN            NaN               NaN
# 2              NaN       NaN            NaN               NaN
# 3              0.0       0.0            0.0              32.0
# 4              NaN       NaN            NaN               NaN
# ...            ...       ...            ...               ...
# 1995           0.0       0.0            0.0              13.0
# 1996           NaN       NaN            NaN               NaN
# 1997           0.0      13.0            0.0               9.0
# 1998           0.0       4.0            0.0              27.0
# 1999           NaN       NaN            NaN               NaN
#
# [2000 rows x 26 columns]

# %%
# 
print(df[df['Cancelled'] != 0].shape[0])
print(df[df['CancellationCode'] != "N"].shape)
# Out:
# 0
# (0, 26)

# %%
df = df.drop(columns=['Cancelled', 'CancellationCode'])
df
# Out:
#       DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0              3          4   2003.0        1955   2211.0        2225
# 1              3          4    754.0         735   1002.0        1000
# 2              3          4    628.0         620    804.0         750
# 3              3          4   1829.0        1755   1959.0        1925
# 4              3          4   1940.0        1915   2121.0        2110
# ...          ...        ...      ...         ...      ...         ...
# 1995           4          5   2038.0        2005   2226.0        2205
# 1996           4          5   1629.0        1615   1828.0        1815
# 1997           4          5   1254.0        1225   1432.0        1350
# 1998           4          5   1702.0        1625   1831.0        1750
# 1999           4          5    916.0         910   1049.0        1055
#
#       FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  ...  Dest  \
# 0           335  N712SW              128.0           150.0  ...   TPA
# 1          3231  N772SW              128.0           145.0  ...   TPA
# 2           448  N428WN               96.0            90.0  ...   BWI
# 3          3920  N464WN               90.0            90.0  ...   BWI
# 4           378  N726SW              101.0           115.0  ...   JAX
# ...         ...     ...                ...             ...  ...   ...
# 1995        977  N363SW              168.0           180.0  ...   SEA
# 1996       2124  N312SW              179.0           180.0  ...   SEA
# 1997        130  N320SW               98.0            85.0  ...   SLC
# 1998       1852  N217JC               89.0            85.0  ...   SLC
# 1999       2360  N494WN               93.0           105.0  ...   SLC
#
#       Distance  TaxiIn TaxiOut Diverted  CarrierDelay  WeatherDelay  NASDelay  \
# 0          810     4.0     8.0        0           NaN           NaN       NaN
# 1          810     5.0    10.0        0           NaN           NaN       NaN
# 2          515     3.0    17.0        0           NaN           NaN       NaN
# 3          515     3.0    10.0        0           2.0           0.0       0.0
# 4          688     4.0    10.0        0           NaN           NaN       NaN
# ...        ...     ...     ...      ...           ...           ...       ...
# 1995      1024     3.0    11.0        0           8.0           0.0       0.0
# 1996      1024     7.0    13.0        0           NaN           NaN       NaN
# 1997       391     4.0    13.0        0          20.0           0.0      13.0
# 1998       391     3.0     9.0        0          10.0           0.0       4.0
# 1999       391     7.0    12.0        0           NaN           NaN       NaN
#
#       SecurityDelay  LateAircraftDelay
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               0.0               32.0
# 4               NaN                NaN
# ...             ...                ...
# 1995            0.0               13.0
# 1996            NaN                NaN
# 1997            0.0                9.0
# 1998            0.0               27.0
# 1999            NaN                NaN
#
# [2000 rows x 24 columns]

# %%
df[df['Diverted'] != 0].shape[0]
# Out:
# 4

# %%
delay_cols = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
df[delay_cols].describe()
# Out:
#        CarrierDelay  WeatherDelay     NASDelay  SecurityDelay  \
# count   1215.000000   1215.000000  1215.000000    1215.000000
# mean      13.090535      0.423868     3.692181       0.099588
# std       23.460437      5.605415    12.308195       0.981270
# min        0.000000      0.000000     0.000000       0.000000
# 25%        0.000000      0.000000     0.000000       0.000000
# 50%        7.000000      0.000000     0.000000       0.000000
# 75%       16.000000      0.000000     4.000000       0.000000
# max      285.000000    135.000000   203.000000      14.000000
#
#        LateAircraftDelay
# count        1215.000000
# mean           29.111111
# std            29.571459
# min             0.000000
# 25%             9.000000
# 50%            21.000000
# 75%            40.000000
# max           263.000000

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0              3          4   2003.0        1955   2211.0        2225
# 1              3          4    754.0         735   1002.0        1000
# 2              3          4    628.0         620    804.0         750
# 3              3          4   1829.0        1755   1959.0        1925
# 4              3          4   1940.0        1915   2121.0        2110
# ...          ...        ...      ...         ...      ...         ...
# 1995           4          5   2038.0        2005   2226.0        2205
# 1996           4          5   1629.0        1615   1828.0        1815
# 1997           4          5   1254.0        1225   1432.0        1350
# 1998           4          5   1702.0        1625   1831.0        1750
# 1999           4          5    916.0         910   1049.0        1055
#
#       FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  \
# 0           335  N712SW              128.0           150.0    116.0     -14.0
# 1          3231  N772SW              128.0           145.0    113.0       2.0
# 2           448  N428WN               96.0            90.0     76.0      14.0
# 3          3920  N464WN               90.0            90.0     77.0      34.0
# 4           378  N726SW              101.0           115.0     87.0      11.0
# ...         ...     ...                ...             ...      ...       ...
# 1995        977  N363SW              168.0           180.0    154.0      21.0
# 1996       2124  N312SW              179.0           180.0    159.0      13.0
# 1997        130  N320SW               98.0            85.0     81.0      42.0
# 1998       1852  N217JC               89.0            85.0     77.0      41.0
# 1999       2360  N494WN               93.0           105.0     74.0      -6.0
#
#       DepDelay Origin Dest  Distance  TaxiIn  TaxiOut  Diverted  CarrierDelay  \
# 0          8.0    IAD  TPA       810     4.0      8.0         0           NaN
# 1         19.0    IAD  TPA       810     5.0     10.0         0           NaN
# 2          8.0    IND  BWI       515     3.0     17.0         0           NaN
# 3         34.0    IND  BWI       515     3.0     10.0         0           2.0
# 4         25.0    IND  JAX       688     4.0     10.0         0           NaN
# ...        ...    ...  ...       ...     ...      ...       ...           ...
# 1995      33.0    DEN  SEA      1024     3.0     11.0         0           8.0
# 1996      14.0    DEN  SEA      1024     7.0     13.0         0           NaN
# 1997      29.0    DEN  SLC       391     4.0     13.0         0          20.0
# 1998      37.0    DEN  SLC       391     3.0      9.0         0          10.0
# 1999       6.0    DEN  SLC       391     7.0     12.0         0           NaN
#
#       WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 0              NaN       NaN            NaN                NaN
# 1              NaN       NaN            NaN                NaN
# 2              NaN       NaN            NaN                NaN
# 3              0.0       0.0            0.0               32.0
# 4              NaN       NaN            NaN                NaN
# ...            ...       ...            ...                ...
# 1995           0.0       0.0            0.0               13.0
# 1996           NaN       NaN            NaN                NaN
# 1997           0.0      13.0            0.0                9.0
# 1998           0.0       4.0            0.0               27.0
# 1999           NaN       NaN            NaN                NaN
#
# [2000 rows x 24 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cmap='viridis')
plt.title('Non a number datas')
# Out:
# Text(0.5, 1.0, 'Non a number datas')

# %%
delay_cols = ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
df[delay_cols] = df[delay_cols].fillna(0)

# %%
df[['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']] = df[['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']].fillna(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              4
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    4
# CRSElapsedTime       0
# AirTime              4
# ArrDelay             4
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               4
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap='viridis')
plt.title('Non a number datas')
# Out:
# Text(0.5, 1.0, 'Non a number datas')

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Unnamed: 0  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1280        1763           3          4    922.0         915      NaN
# 1372        1911           3          4   2325.0        1900      NaN
# 1776        2651           4          5   1949.0        1905      NaN
# 1831        2726           4          5    737.0         705      NaN
#
#       CRSArrTime UniqueCarrier  FlightNum TailNum  ...  TaxiIn  TaxiOut  \
# 1280        1050            WN       1069  N630WN  ...     NaN     12.0
# 1372        2030            WN       2092  N302SW  ...     NaN     11.0
# 1776        1910            WN       1403  N504SW  ...     NaN     11.0
# 1831         825            WN        178  N718SW  ...     NaN     13.0
#
#       Cancelled  CancellationCode  Diverted CarrierDelay WeatherDelay  \
# 1280          0                 N         1          0.0          0.0
# 1372          0                 N         1          0.0          0.0
# 1776          0                 N         1          0.0          0.0
# 1831          0                 N         1          0.0          0.0
#
#       NASDelay  SecurityDelay  LateAircraftDelay
# 1280       0.0            0.0                0.0
# 1372       0.0            0.0                0.0
# 1776       0.0            0.0                0.0
# 1831       0.0            0.0                0.0
#
# [4 rows x 28 columns]

# %%
df = df.dropna(subset=['ArrTime','ActualElapsedTime','AirTime','ArrDelay','TaxiIn'])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# CancellationCode     0
# Diverted             0
# CarrierDelay         0
# WeatherDelay         0
# NASDelay             0
# SecurityDelay        0
# LateAircraftDelay    0
# dtype: int64
